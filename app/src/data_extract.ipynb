# %%
from PyPDF2 import PdfFileReader
import os
import json
import pandas as pd

# %% [markdown]
# Extract information from pdf file

# %%
def extract_pdf(path):
    pdf=PdfFileReader(path, strict=False)
    number_pages=pdf.getNumPages()
    content=''
    for i in range(number_pages):
        content+=pdf.getPage(i).extractText()
    
    content=content.replace('\n','. ').replace('\n\n','. ')
    content=content.replace('\t',' ')
    
    return content

# %% [markdown]
# Get path to each pdf file stored in folder

# %%
def get_path_pdf(path_folder):
    path_pdf=[]
    for dirname,_,filenames in os.walk(path_folder):
        for filename in filenames:
            path_pdf.append(os.path.join(dirname,filename))
    return path_pdf

# %% [markdown]
# Read JD

# %%
path_JD="./static/files_JD/"
path_2_pdfJD=get_path_pdf(path_JD)
content_JD=extract_pdf(path_2_pdfJD[0])

# %% [markdown]
# Read CV

# %%
path_CV="./static/files_CV/"
path_2_pdfCV=get_path_pdf(path_CV)
content_CV=[]
for p in path_2_pdfCV:
    content_CV.append(extract_pdf(p))

# %% [markdown]
# Using Spacy to extract skill

# %%
from spacy.pipeline import EntityRuler
from spacy import displacy
import jsonlines
import spacy
import re 
import pyperclip
from sympy import true

# %%
json_path="skill_paterns.jsonl"

with jsonlines.open(json_path) as f:
    entities=[line["label"].upper() for line in f.iter()]

# spacy model
nlp=spacy.load("en_core_web_lg")

# %%
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk(json_path)

# %%
doc=nlp(content_CV[0])

# %%
for sent in (list(doc.sents)):
    tmp=sent.text.split(" ")
    for wolrd in tmp:
        wolrd=wolrd.lower()
        if(wolrd=='experience'):
            print(sent)
            print('===')

# %% [markdown]
# PERSONAL INFORMATION

# %%
def get_skill(content_CV):
    doc=nlp(content_CV)
    skill_list=[]
    for ent in doc.ents:
        if ent.label_=='SKILL':
            skill_list.append(ent.text)
    skill_list=list(set(skill_list))
    return skill_list

def get_GPA(content_CV):
    doc=nlp(content_CV)
    sent=list(doc.sents)
    gpa=''
    for s in sent:
        s=s.text
        if s.find('GPA') !=-1 :
            gba_pos= s.find('GPA') 
            for i in range (gba_pos+3,gba_pos+8):
                if (s[i] >'0' and s[i]<'9' or s[i]=='.'):
                    gpa+=s[i]
    if gpa=='':
        return None
    else:
        return gpa

def get_experience(content_CV):
    '''
    Return\n
        None if no experience\n
        List of experience if exist
    '''
    doc=nlp(content_CV)
    sent=list(doc.sents)
    final_res=''
    ex=[]
    for s in sent:
        s_text=s.text.split(' ')
        flag=False
        for i in s_text:
            i=i.lower()
            if i=='experience':
                flag=True
        if flag==True:
            ex.append([s.text])
    if (len(ex)==0):
        final_res=None
    else:
        final_res=ex
    return final_res

def get_education(content_CV):
    doc=nlp(content_CV)
    sent=list(doc.sents)
    edu=''
    pos_edu=-1
    pos_edu_end=-1
    for s in sent:
        s_text=s.text.lower()
        flag=False
        if s_text.find('education')!=-1 or s_text.find('university')!=-1 or s_text.find('academic')!=-1 or s_text.find('bachelor ')!=-1:
            edu =s.text
            if s_text.find('education')!=-1 :
                pos_edu=s_text.find('education')+9
            if s_text.find('academic') !=-1 :
                pos_edu=s_text.find('academic')
            if s_text.find('university') !=-1 :
                pos_edu=s_text.find('university')
            else:
                pos_edu=s_text.find('bachelor ')
            
            pos_edu_end=s_text.find('. ',pos_edu)
            edu=edu[pos_edu:pos_edu_end]
    if edu=='':
        return None
    else:
        return edu

def get_phone(content_CV):
    '''
    Format for Phone-Numbers:
    134567890
    123-456-7890
    (123)(456)(7890)
    123.456.7890
    (123)(456-7890)
    '''
    phone= re.compile(r'''
        (\d{3}|\(\d{3}\))    
        (\s|-|\.)?           
        (\d{3}|\(\d{3}\))    
        (\s|-|\.)?           
        (\d{4}|\(\d{4}\))    
    ''', re.VERBOSE) 

    matchs=phone.finditer(content_CV)
    res = ''
    for match in matchs:
        res+=match.group(0)
    if res=='':
        return None
    else:
        return res

def get_link(link,content_CV):
    matchs=link.finditer(content_CV)
    res=''
    for match in matchs:
        res+=match.group(0)
    if res=='':
        return None
    else:
        return res

# %% [markdown]
# NAME

# %%
from spacy.tokens import Span
import dateparser
def expand_person_entities(doc):
    new_ents = []
    for ent in doc.ents:
        # Only check for title if it's a person and not the first token
        if ent.label_ == "PERSON":
            if ent.start != 0:
                # if person preceded by title, include title in entity
                prev_token = doc[ent.start - 1]
                if prev_token.text in ("Dr", "Dr.", "Mr", "Mr.", "Ms", "Ms."):
                    new_ent = Span(doc, ent.start - 1, ent.end, label=ent.label)
                    new_ents.append(new_ent)
                else:
                    # if entity can be parsed as a date, it's not a person
                    if dateparser.parse(ent.text) is None:
                        new_ents.append(ent) 
        else:
            new_ents.append(ent)
    doc.ents = new_ents
    return doc

# Add the component after the named entity recognizer
# # nlp.remove_pipe('expand_person_entities')
# @Language.component("expand_person_entities")
# nlp.add_pipe("expand_person_entities", after='ner')

# doc = nlp(content_CV[0])
# [(ent.text, ent.label_) for ent in doc.ents if ent.label_=='PERSON']

# %%
from spacy.matcher import Matcher
# initialize matcher with a vocab

def extract_name(content_CV):
    matcher = Matcher(nlp.vocab)
    doc=nlp(content_CV)
    error_key=['city','school','university','freelancer','building']
    warning_key=['curriculum vita']
    cut_pos=-1
    # Fisrt way: using ner in spacy
    for ent in doc.ents:
        if ent.label_=='PERSON':
            txt=ent.text
            txt_lower=txt.lower()
            flag=True
            for i in error_key:
                if i in txt_lower:
                    flag=False
            for j in warning_key:
                if j in txt_lower:
                    cut_pos=txt_lower.find(j)
                    txt=txt[:cut_pos]
            if flag==True:
                return txt
            else:
                break
    # Second way: First name and Last name are always Proper Nouns
    pattern = [
        {'POS': 'PROPN'},{'POS': 'PROPN'},
        ]

    matcher.add('NAME',[pattern])
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        return span.text
    return None

extract_name(content_CV[5])
# Out:
# 'là sinh'

# %% [markdown]
# Check Accuracy of name

# %%
# train_data = json.load(open('./data/training/train_data.json','rb')) 

def name_acc(train_data):
    list_an=[]
    list_txt=[]
    name=[]

    for text,annotation in train_data:
        list_an.append(list(annotation.values()))
        list_txt.append(text)

    target_name=[]
    predic_name=[]

    similar=0
    for i in range(len(list_an)):
        t=''
        p=''
        p=extract_name(list_txt[i])
        predic_name.append(p)
        for j in range(len(list_an[i][0])):
            if list_an[i][0][j][2]=='Name':
                t=list_txt[i][list_an[i][0][j][0]:list_an[i][0][j][1]]
                target_name.append(t)
        if t==p:
            similar+=1
    return (similar/len(list_an)*100)    
# name_acc(train_data)

# %% [markdown]
# Load accuracy name

# %%
nlp_model=spacy.load('nlp_model')

# %% [markdown]
# Using sklearn to calculate the cosine similarity score of CV and JD

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Cleaning data

# %%
def cosine_similar(list_CV,JD):
    df_rank_match=pd.DataFrame(columns=['ID','Percent_Match_JD'])
    for i in range(len(list_CV)):
        test=[list_CV[i],JD]
        cv = CountVectorizer()
        count_matrix= cv.fit_transform(test)
        match=cosine_similarity(count_matrix)        
        row = {
            'ID':i,
            'Percent_Match_JD': round(match[0][1]*100,2)
        }
        new_df=pd.DataFrame([row])
        df_rank_match=pd.concat([df_rank_match,new_df],axis=0,ignore_index=True)
    return df_rank_match

# %% [markdown]
# Final extract and save to dataframe

# %%
def extract_all_data(list_content_CV,content_JD):
    df_match=cosine_similar(list_content_CV,content_JD)
    extract_df_match=df_match["Percent_Match_JD"]

    label=['ID','Email','Phone_Number','Related_Link','Skill','Experience','Education','GPA']

    df_information = pd.DataFrame(columns=label) 
    # bitbucket
    mail = re.compile(r'[a-zA-Z0-9-\.]+@[a-zA-Z-\.]*\.(com|edu|net|vn)')
    
    git = re.compile(r'(gitlab.com/|github.com/)+[a-zA-Z0-9-\.]*')
    web = re.compile(r'(http://|https:// )+[a-zA-Z0-9-"/"-\.]*')
    linkedin = re.compile(r'linkedin.com/+[a-zA-Z0-9-"/"-\.]*')

    for i in range(len(list_content_CV)):
        content=list_content_CV[i]
        link=[]
        link.append(get_link(git,content))
        link.append(get_link(web,content))
        link.append(get_link(linkedin,content))
        
        row={
                'ID':i,
                # 'Name':extract_name(content),
                'Email':get_link(mail,content),
                'Phone_Number':get_phone(content),
                'Related_Link':link,
                'Skill':get_skill(content),
                'Experience':get_experience(content),
                'Education':get_education(content),
                # 'GPA':get_GPA(content)
            }
        new_df=pd.DataFrame([row])
        df_information=pd.concat([df_information,new_df],axis=0,ignore_index=True)
    df_information=df_information.join(extract_df_match)
    df_information=df_information.sort_values(by='Percent_Match_JD', ascending=False)
    return df_information


# list_CV=[]
# count=0
# train_data = json.load(open('./data/training/train_data.json','rb')) 

# for text,annotation in train_data:
#     count+=1
#     list_CV.append(text)
#     if count==50:
#         break

df_detail=extract_all_data(content_CV,content_JD)

# Modify the column widths to fit the contents
pd.set_option("display.max_colwidth", None)
df_detail
# Out:
#     ID  \
# 3    3
# 17  17
# 20  20
# 31  31
# 1    1
# 6    6
# 27  27
# 30  30
# 21  21
# 16  16
# 11  11
# 14  14
# 26  26
# 13  13
# 7    7
# 15  15
# 23  23
# 28  28
# 4    4
# 24  24
# 8    8
# 12  12
# 18  18
# 10  10
# 29  29
# 22  22
# 5    5
# 9    9
# 25  25
# 19  19
# 2    2
# 0    0
#
#                                                                                 Email  \
# 3                                                          nghiem0859774418@gmail.com
# 17                                                                               None
# 20                                                                cbt270801@gmail.com
# 31                                                       tranhieukhoa442001@gmail.com
# 1                                                                 vutammcpe@gmail.com
# 6                                                                quanlh0606@gmail.com
# 27                                                          letanphuc142001@gmail.com
# 30                                                              ngnglinhbao@gmail.com
# 21                                                               tonycao312@gmail.com
# 16                                                   Cityvothanhnam18092001@gmail.com
# 11                                                                nghiaapag@gmail.com
# 14                                                                  vhduy23@gmail.com
# 26                                                          lephongplus2016@gmail.com
# 13                                                          phananhnhat0812@gmail.com
# 7                                                              enanhphu1911@gmail.com
# 15                                                            vuhongthien18@gmail.com
# 23                                                                an2703201@gmail.com
# 28  lethevinh1997@gmail.comv89@example.nethiep.chuong@example.comintron.0x@icloud.com
# 4                                                          caonhatkhang2001@gmail.com
# 24                                                               envu191000@gmail.com
# 8                                                    nguyentrinhhoangphuong@gmail.com
# 12                                                            quocmanh1998s@gmail.com
# 18                                                             tinh.vtq@kissyo.edu.vn
# 10                                                           namtanbinh0147@gmail.com
# 29                                                                 hp205125@gmail.com
# 22                                                        dangquangminhdn86@gmail.com
# 5                                                                                None
# 9                                                          nguyenkhai250419@gmail.com
# 25                                                                 hovi2711@gmail.com
# 19                                                                xsang1317@gmail.com
# 2                                                      huynhthithuydung2707@gmail.com
# 0                                                                 htran9776@gmail.com
#
#                                                     Phone_Number  \
# 3                                           08597744180859774418
# 17  876559927381150312538765599273876559927387655992738765599273
# 20                                                    0972707663
# 31                                                          None
# 1                                                     0352967123
# 6                                                           None
# 27                                                    0829069600
# 30                                                    6142439564
# 21                                          03724918520372491852
# 16                                                  039-252-5473
# 11                                                    0977949890
# 14                                                          None
# 26                                                    0372546237
# 13                                                    0908631492
# 7                                                     0738421397
# 15                                                    0398073470
# 23                                                    0377421240
# 28                                                    0586801768
# 4                                                     0889066088
# 24                                                    0914684169
# 8                                                     0788565437
# 12                                                    0826572751
# 18                                                    0972277754
# 10                                                    0934697602
# 29                                                    0853736682
# 22                                                    0898479840
# 5                                                    084531 1020
# 9                                                     0973548264
# 25                                                    0899385753
# 19                                                    0934101207
# 2                                                     0934147908
# 0                                                     0972902961
#
#                                                                                                                           Related_Link  \
# 3                                                                 [github.com/TruongChiNghiem1., http://dentistrychinghiem.tk/., None]
# 17                                                                                                                  [None, None, None]
# 20                                                                                               [github.com/BaoThai0605., None, None]
# 31                                                            [gitlab.com/tranhieukhoa.github.com/hiukhoago, None, linkedin.com/in/k.]
# 1                                                                                                                   [None, None, None]
# 6                                                                                                                   [None, None, None]
# 27                           [github.com/ltphuc2001.github.com/ltphuc2001github.com/ltphuc2001, http://ltpbookstore.epizy.com/., None]
# 30              [github.com/nglinhbaoContactgithub.com/nglinhbaogithub.com/nglinhbaogithub.com/minhpggithub.com/nglinhbao, None, None]
# 21                                                                                                                  [None, None, None]
# 16                                                                    [github.com/Thanh-Nam-1809github.com/Thanh-Nam-1809, None, None]
# 11                                                                                                                  [None, None, None]
# 14                                                                                  [github.com/vhduy23github.com/vhduy23, None, None]
# 26                                                                                            [github.com/lephongplus201., None, None]
# 13                                                                                                 [github.com/AnhNhat111, None, None]
# 7                                                                          [github.com/Nguygithub.com/Nguygithub.com/Nguy, None, None]
# 15                                                                                               [github.com/vuhongthien., None, None]
# 23                                                                                                                  [None, None, None]
# 28                                                  [github.com/mian17github.com/mian17github.com/mian17github.com/mian17, None, None]
# 4                                                 [github.com/nhatkhangcaogithub.com/nhatkhangcaogithub.com/nhatkhangcao., None, None]
# 24                                                                         [github.com/nguygithub.com/nguygithub.com/nguy, None, None]
# 8                                            [github.com/hoangphuong965github.com/hoangphuong965github.com/hoangphuong965, None, None]
# 12                                                      [github.com/quocmanh98github.com/quocmanhh99github.com/quocmanh98, None, None]
# 18                                                                [github.com/vchie.github.com/vchieu7301, None, linkedin.com/in/chi.]
# 10                                                                                                [github.com/TanBinhNam., None, None]
# 29                                                                    [github.com/Manghongphuonggithub.com/Manghongphuong, None, None]
# 22                                                                                               [github.com/dangquangmi., None, None]
# 5   [github.com/cass.github.com/cassle123github.com/cassle123github.com/cassle123github.com/cassle123github.com/cassle123, None, None]
# 9                                                                                                                   [None, None, None]
# 25                                                                                [github.com/viho1906github.com/viho1906, None, None]
# 19                                                                                                                  [None, None, None]
# 2                                                                                                                   [None, None, None]
# 0                                                                                                                   [None, None, None]
#
#                                                                                                                                                                                                                                 Skill  \
# 3                                                                                                                                                                                            [Laravel, MySQL, Ranking, PHP, schedule]
# 17                                                                                        [shrinkage, design, Engineering, Documentation, mode, Languages, software, Simulation, First Class, 3D, Software, Specification, component]
# 20                                                                                                                                 [design, SQL, Framework, Firebase, software engineering, Javascript, PHP, C, Certificate, MongoDB]
# 31     [SQL, React Native, CERTIFICATE, CSS, mobile, certificate, design, Flutter, Trello, GitLab, database, User interface, Laravel, framework, Bootstrap, Design, HTML, Figma, MySQL, Git, API, PHP, Tailwind CSS, GitHub, MongoDB]
# 1                                                                                                                                                               [Algorithms, ASP.NET, PHP, Computer Science, languages, Python, play]
# 6                                                                                                                                               [SQL, MYSQL, Software Engineering, .NET, PHP, C, Software, CSS, HTML, user interface]
# 27                                                             [design, Laravel, SQL, GitHub, Programming Language, MySQL, Jquery, Javascript, Database, Computer Science, PHP, CSS, Ajax, HTML, Python, algorithms, data structures]
# 30                                                                                                                                              [MySQL, Machine Learning, PHP, Computer Science, CSS, HTML, Python, algorithms, Ruby]
# 21                                                                                                                       [SQL, Framework, Software Engineering, library, software, .NET, PHP, C, Android, CSS, ASP.NET, Design, HTML]
# 16                                                                                                                                                                        [JavaScript, Github, PHP, CSS, Mobile, HTML, play, Node JS]
# 11  [SQL, MYSQL, Visual basic, COMMERCE, Database, Computer Science, CSS, Ajax, Certificate, Wordpress, C++, Laravel, Sublime Text, HTML, Visual Studio, Framework, MySQL, Jquery, libraries, PHP, support, Java, Server, JSON, play]
# 14                                                                                                           [SQL, Ecommerce, API, Git, Jquery, Github, .NET, database, Javascript, Database, PHP, R, CSS, C, github, SOFTWARE, HTML]
# 26                                                                                                                      [Mongodb, database design, MySQL, Git, API, MySql, web app, Database, PHP, Google, Computer science, MongoDB]
# 13                                                                                                                                    [Laravel, framework, Flutter, database design, API, Angular, Languages, Javascript, PHP, Mysql]
# 7                                                                                                                                                                                    [Laravel, SQL, MySQL, PHP, C, CSS, github, HTML]
# 15                                                                                               [SQL, Framework, FRAMEWORK, MySQL, Languages, Databases, Spring Boot, SPRING, PHP, C, Ajax, CSS, Design, HTML, Programming language]
# 23                                                                                                                                                      [design, Laravel, Framework, MySQL, Angular, Git, Database, PHP, CSS, GitHub]
# 28                [React, JavaScript, CERTIFICATE, COMMERCE, Database, CSS, PROGRAMMING LANGUAGE, Pusher, React Router, C, languages, MacOS, Laravel, Source code, Design, HTML, MariaDB, MySQL, Git, Ubuntu, PHP, GitHub, Bootstrap]
# 4                                                                                                                                          [robot, MySQL, Git, Github, Javascript, Database, PHP, CSS, Computer Engineering, arduino]
# 24                                                                                                                                                                                    [API, CSS, HTML, Programming language, MongoDB]
# 8                                                                                                                                                                             [Laravel, React, MySQL, Github, PHP, CSS, github, HTML]
# 12                                                                                            [Laravel, Framework, MYSQL, JavaScript, API, Github, database, Postman, Database, PHP, CSS, Ajax, source code, Design, HTML, Bootstrap]
# 18                                                                                                                     [Laravel, SQL, Framework, framework, MySQL, Visual Studio Code, Github, Javascript, PHP, C, CSS, HTML, Server]
# 10                                                                                                                                                          [Laravel, JQuery, Framework, MySQL, Javascript, Database, PHP, CSS, HTML]
# 29                                                                                                                                                                             [SQL, jQuery, MySQL, Angular, JavaScript, Github, PHP]
# 22                                                                                                                                                                                            [SQL, Angular, PHP, CSS, angular, HTML]
# 5                                                                     [SQL, Laravel, ExpressJS, MySQL, VueJS, Google Maps, API, Socket.io, Github, Android Studio, Javascript, Database, PHP, Google, CSS, source code, HTML, Server]
# 9                                                                                                                                          [SQL, MySQL, Visual Studio Code, Javascript, Database, ASP.NET, C, CSS, PHP, HTML, Server]
# 25                                                                                                                                                         [MySQL, Angular, VueJS, Vuejs, ES6, PHP, C, CSS, HTML, Wordpress, MongoDB]
# 19                                                                                                                                                       [MYSQL, API, Angular, MySQL, Visual Studio Code, database, Google, PHP, CSS]
# 2                                                                                                                                                                                                    [Visual Studio, SQL, PHP, MySQL]
# 0                                                                                                                                                                                                                [AVA, SQL, C, MySQL]
#
#                                                                                                                                    Experience  \
# 3                                                                                         [[knowledge and experience to become an official.]]
# 17                                                                                                                                       None
# 20                                                                                                                                       None
# 31                                                            [[working hard to learn f rom internet and experience form .], [EXPERIENCE  .]]
# 1                                                         [[- Acquired communication and problem-solving skillsWork experience Objectives .]]
# 6                                                                                                                                        None
# 27                                                                                        [[Learn a lot of experience from the forerunners.]]
# 30                                                                                                                                       None
# 21                                                                       [[and gain more experience in a positive environment.. EDUCA TION.]]
# 16                                                                                                                                       None
# 11                                                                                                                                       None
# 14                                                                                                                                       None
# 26                                                                                                                                       None
# 13                                                                              [[I want t o gain a lot of knowledge and experience in PHP.]]
# 7   [[The accumulated pr actical work experience will be the basis for achie ving the. goal of becoming a good pr ogrammer in the futur e..]]
# 15                                                                                                                                       None
# 23                                                                                                                                       None
# 28                                                                                                                                       None
# 4                                                                                                                                        None
# 24                                                                                                                                       None
# 8                                                                                                                                        None
# 12                                                                                                                                       None
# 18                                                                                                                                       None
# 10                                                                                                                                       None
# 29                                                                                                                                       None
# 22                                                                                                                                       None
# 5                                                                                                                                        None
# 9                                                                                                                                        None
# 25                                                                                                                                       None
# 19                                                                                                                                       None
# 2                                                                                                                                        None
# 0                                                                                                                                        None
#
#                                                                                                       Education  \
# 3                                                                                                          None
# 17  Bachelor in Mechanical Engineering, Seth Sriniwas Agarwal Institute of Engineering & Technology (U.P.T.U) ,
# 20                                                                                                   University
# 31                                                                                                         None
# 1                                                                                                    University
# 6                                                                      University of Education (2019 - Present)
# 27                                                                                          University HCM City
# 30                                                                                                         None
# 21                                                                                                  University
# 16                                                                                                         None
# 11                                                                                                         None
# 14                                                                                                   University
# 26                                                                                                         None
# 13                                                                                                         None
# 7                                                                                                          None
# 15                                                                                                         None
# 23                                                                                                         None
# 28                                               UNIVERSITY OF SOCIAL SCIENCES & HUMANITIES, HCMCCERTIFICATIONS
# 4                                                                                                          None
# 24                                                                                                         None
# 8                                                                                                          None
# 12                                                                                                         None
# 18                                                                                                         None
# 10                                                                                                         None
# 29                                                                                                         None
# 22                                                                                                         None
# 5                                                                                                          None
# 9                                                                                                          None
# 25                                                                                                         None
# 19                                                                                                         None
# 2                                                                                                          None
# 0                                                                                                          None
#
#     GPA  Percent_Match_JD
# 3   NaN             42.81
# 17  NaN             41.07
# 20  NaN             37.16
# 31  NaN             36.40
# 1   NaN             35.09
# 6   NaN             33.82
# 27  NaN             30.70
# 30  NaN             28.24
# 21  NaN             27.58
# 16  NaN             27.57
# 11  NaN             26.52
# 14  NaN             25.98
# 26  NaN             25.64
# 13  NaN             19.87
# 7   NaN             17.96
# 15  NaN             17.22
# 23  NaN             16.84
# 28  NaN             13.45
# 4   NaN             12.42
# 24  NaN             11.23
# 8   NaN             11.07
# 12  NaN              5.70
# 18  NaN              4.32
# 10  NaN              3.54
# 29  NaN              3.25
# 22  NaN              3.03
# 5   NaN              2.04
# 9   NaN              1.87
# 25  NaN              1.60
# 19  NaN              1.30
# 2   NaN              0.59
# 0   NaN              0.00
